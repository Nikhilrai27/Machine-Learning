# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_regression

# %%
x,y=make_regression(
    n_samples=1000,
    n_features=2,
    noise=10,
    random_state=42,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
regressor=KNeighborsRegressor( n_neighbors=6,
    algorithm='auto')

# %%
regressor.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=6)

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.9189275159979495
# 9.009462452972217
# 127.45860414317289

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={'n_neighbors':[3,5,7,10,20,25,50],
    'weights':['uniform','distance'],
    'algorithm' : [ 'ball_tree', 'kd_tree', 'brute'],
}

# %%
grid=GridSearchCV(estimator=KNeighborsRegressor(),param_grid=params, cv=5,scoring='neg_mean_squared_error'
)

# %%
grid.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(),
#              param_grid={'algorithm': ['ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 10, 20, 25, 50],
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'algorithm': 'ball_tree', 'n_neighbors': 7, 'weights': 'distance'}

# %%
grid.best_score_
# Out:
# -129.4716094734302

# %%
results = pd.DataFrame(grid.cv_results_)
print(results.head())
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.000313      0.000443         0.001012        0.000626
# 1       0.000467      0.000933         0.000921        0.001202
# 2       0.000000      0.000000         0.001359        0.001229
# 3       0.000558      0.000509         0.002178        0.001341
# 4       0.000400      0.000490         0.000977        0.000562
#
#   param_algorithm  param_n_neighbors param_weights  \
# 0       ball_tree                  3       uniform
# 1       ball_tree                  3      distance
# 2       ball_tree                  5       uniform
# 3       ball_tree                  5      distance
# 4       ball_tree                  7       uniform
#
#                                               params  split0_test_score  \
# 0  {'algorithm': 'ball_tree', 'n_neighbors': 3, '...        -151.816688
# 1  {'algorithm': 'ball_tree', 'n_neighbors': 3, '...        -154.605547
# 2  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...        -130.529619
# 3  {'algorithm': 'ball_tree', 'n_neighbors': 5, '...        -137.146550
# 4  {'algorithm': 'ball_tree', 'n_neighbors': 7, '...        -131.720687
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0        -151.512922        -154.021409        -107.608618        -140.025181
# 1        -151.293677        -154.633806        -111.959610        -143.303942
# 2        -149.999634        -150.009250        -105.829843        -126.669735
# 3        -148.658461        -145.465178        -105.509044        -127.942386
# 4        -146.507529        -158.660799        -108.580750        -112.570978
#
#    mean_test_score  std_test_score  rank_test_score
# 0      -140.996964       17.395482               22
# 1      -143.159316       16.138715               25
# 2      -132.607616       16.504089               10
# 3      -132.944324       15.485984               13
# 4      -131.608149       19.217310                7
